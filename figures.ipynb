# %%
# !pip install ipython==8.12.2 matplotlib==3.7.1 pandas==2.0.1 kaleido==0.2.1 numpy==1.24.3 plotly==5.14.1

import os

os.mkdirs('/home/croderog/Desktop/IC_projects/ISCTs_review/figures',exist_ok=True)
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 5
#       1 get_ipython().system('pip install ipython==8.12.2 matplotlib==3.7.1 pandas==2.0.1 kaleido==0.2.1 numpy==1.24.3 plotly==5.14.1')
#       3 import os
# ----> 5 os.mkdirs('/home/croderog/Desktop/IC_projects/ISCTs_review/figures',exist_ok=True)
#
# AttributeError: module 'os' has no attribute 'mkdirs'

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
original_data = [{'id': 27,   'sample': 'twinned', 'trial': False, 'SA': False, 'any_validation': True, 'industrial_funding': False, 'physics': ['fluids'], 'intervention': 'fistula occlusion', 'anatomy': ['aorta', 'coronary arteries'], 'software': ['simvascular'], 'demographics': {'sex': True, 'age': True, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 12, 'condition': 'coronary artery fistula', 'females': 3, 'n_patients': 4, 'year': 2020, 'first_author_country': {'China': 1},                        'all_authors_countries': {'China': 8}},
                 {'id': 170,  'sample': 'twinned', 'trial': 'Randomized controlled trial', 'SA': False,'any_validation': True, 'industrial_funding': False, 'physics': ['fluids'], 'intervention': 'stent placement', 'anatomy': ['aorta'], 'software': ['ZIB-Amira', 'Fluent'], 'demographics': {'sex': True, 'age': True, 'BMI': False, 'weight': True, 'NA': False, 'ethnicity': False, 'comorbidities': True}, 'original_data': True, 'data_availability': 'Available upon request', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 5, 'condition': 'aortic recoarctation','females': 0, 'n_patients': 3, 'year': 2019, 'first_author_country': {'UK': 1},                           'all_authors_countries': {'UK': 5, 'Germany': 4, 'Sweden': 1}},
                 {'id': 183,  'sample': 'population', 'trial': False, 'SA': 'The whole study could be considered a SA','any_validation': False, 'industrial_funding': True, 'physics': ['electrophysiology'], 'intervention': 'drug delivery', 'anatomy': ['cell'], 'software': ['Matlab', 'CellML', 'C++', 'CVODE', 'Chaste'],  'demographics': {'sex': False, 'age': False, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Data and scripts shared', 'open_access': True, 'computer': 'Desktop, 1 core', 'n_simulations': 'Many – no exact number. 200 simulations for each concentration for each drug', 'condition': 'healthy','females': float('Nan'), 'n_patients': float('NaN'), 'year': 2013, 'first_author_country': {'UK': 1},                           'all_authors_countries': {'UK': 7}},
                 {'id': 482,  'sample': 'twinned', 'trial': False, 'SA': False, 'any_validation': False, 'industrial_funding': True, 'physics': ['mechanics', 'fluids'], 'intervention': 'CRT', 'anatomy': ['LV', 'RV'], 'software': ['CircAdapt'],'demographics': {'sex': False, 'age': False, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': False, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 102, 'condition': 'HF','females': float('Nan'), 'n_patients': 51, 'year': 2018, 'first_author_country': {'France': 1, 'The Netherlands': 1}, 'all_authors_countries': {'France': 7, 'The Netherlands': 6}},
                 {'id': 609,  'sample': 'hybrid twinned', 'trial': False, 'SA': False, 'any_validation': True, 'industrial_funding': False, 'physics': ['electrophysiology'], 'intervention': 'ablation', 'anatomy': ['LV', 'RV', 'torso'], 'software': ['openCARP'],'demographics': {'sex': False, 'age': False, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': True}, 'original_data': False, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 'Not reported', 'condition': 'AF','females': float('Nan'), 'n_patients': 10, 'year': 2021, 'first_author_country': {'Germany': 1},                      'all_authors_countries': {'Germany': 8, 'Italy': 2, 'UK': 1, 'Spain': 2, 'Brazil': 1}},
                 {'id': 1625, 'sample': 'twinned', 'trial': False, 'SA': False, 'any_validation': False, 'industrial_funding': False, 'physics': ['fluids'], 'intervention': 'magnetic field application', 'anatomy': ['coronary arteries'], 'software': ['Ansys meshing', 'Fluent', 'graphpad prism'],'demographics': {'sex': True, 'age': True, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': False, 'computer': 'Not reported', 'n_simulations': 'Not reported', 'condition': 'atherosclerosis','females': 4, 'n_patients': 25, 'year': 2018, 'first_author_country': {'Australia': 1},                    'all_authors_countries': {'Australia': 2, 'Iran': 2}},
                 {'id': 1720, 'sample': 'twinned', 'trial': False, 'SA': False, 'any_validation': False, 'industrial_funding': True, 'physics': ['fluids'], 'intervention': 'stent placement', 'anatomy': ['coronary arteries'], 'software': ['Ansys'],'demographics': {'sex': True, 'age': True, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': True}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': False, 'computer': 'Not reported', 'n_simulations':  66, 'condition': 'coronary lesion','females': 8, 'n_patients': 22, 'year': 2021, 'first_author_country': {'USA': 1},                          'all_authors_countries': {'USA': 6, 'Greece': 4, 'Germany': 4, 'Brazil': 2, 'The Netherlands': 2, 'Belgium': 1, 'Denmark': 1}},
                 {'id': 1749, 'sample': 'twinned', 'trial': 'Clinical trial', 'SA': False, 'any_validation': True, 'industrial_funding': True, 'physics': ['fluids', 'mechanics'], 'intervention': 'Fontan surgery', 'anatomy': ['Fontan conduit'], 'software': ['simvascular'], 'demographics': {'sex': False, 'age': False, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Available upon request', 'open_access': True, 'computer': 'Not reported', 'n_simulations':  24, 'condition': 'univentricular CHD','females': float('Nan'), 'n_patients': 4, 'year': 2021,  'first_author_country': {'USA': 1}, 'all_authors_countries': {'USA': 14}},
                 {'id': 1766, 'sample': 'twinned', 'trial': False, 'SA': False,'any_validation': True, 'industrial_funding': False, 'physics': ['mechanics'], 'intervention': 'valve replacement', 'anatomy': ['LV', 'RV'], 'software': ['QMass', 'ADINA'], 'demographics': {'sex': True, 'age': True, 'BMI': True, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Data will be made available, nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations':  147, 'condition': 'Tetrallogy of Fallot','females': 3, 'n_patients': 7, 'year': 2021, 'first_author_country': {'China': 1}, 'all_authors_countries': {'China': 3, 'USA': 7}},
                 {'id': 1810, 'sample': 'twinned', 'trial': False, 'SA': False,'any_validation': True, 'industrial_funding': False, 'physics': ['fluids','mechanics'], 'intervention': ['stent placement', 'double outlet RV repair'], 'anatomy': ['LV', 'RV', 'LA', 'RA', 'aorta', 'pulmonary artery', 'coronary arteries'], 'software': ['Mimics', 'ScanIp', 'VMTKLab', 'ITKSnap', 'OsiriX', 'Abaqus', 'Fluent'],'demographics': {'sex': False, 'age': True, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': True}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations':  12, 'condition': 'congenital heart disease','females': float('Nan'), 'n_patients': 12, 'year': 2018, 'first_author_country': {'UK': 1}, 'all_authors_countries': {'UK': 9, 'Italy': 2, 'South Africa': 1}},
                 {'id': 1826, 'sample': 'twinned', 'trial': False, 'SA': False,'any_validation': False, 'industrial_funding': True, 'physics': ['electrophysiology'], 'intervention': 'ICD', 'anatomy': ['LV', 'RV', 'torso'], 'software': ['Seg3D', 'meshtool'],'demographics': {'sex': True, 'age': True, 'BMI': True, 'weight': True, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations':  5, 'condition': 'chest pain','females': 2, 'n_patients': 5, 'year': 2019, 'first_author_country': {'UK': 1}, 'all_authors_countries': {'UK': 9, 'Austria': 2, 'USA': 1}},
                 {'id': 1858, 'sample': 'twinned', 'trial': False, 'SA': False,'any_validation': True, 'industrial_funding': False, 'physics': ['fluids'], 'intervention': 'valve replacement', 'anatomy': ['aorta'], 'software': ['3DSlicer', 'Geomagic Studio', 'Ansys CFX', 'SPSS'],'demographics': {'sex': True, 'age': True, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations':  6, 'condition': 'aortic stenosis','females': float('Nan'), 'n_patients': 6, 'year': 2020, 'first_author_country': {'USA': 1}, 'all_authors_countries': {'USA': 8, 'Germany': 2, 'Canada': 1}},
                 {'id': 1868, 'sample': 'twinned', 'trial': False, 'SA': False,'any_validation': False, 'industrial_funding': False, 'physics': ['fluids'], 'intervention': 'Fenestrated endovascular aneurysm repair', 'anatomy': ['aorta'], 'software': ['simvascular'],'demographics': {'sex': False, 'age': False, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Cluster using 72 cores', 'n_simulations':  10, 'condition': 'aortic aneurysm','females': float('Nan'), 'n_patients': 10, 'year': 2021, 'first_author_country': {'USA': 1}, 'all_authors_countries': {'USA': 5}},
                 {'id': 1874, 'sample': 'twinned', 'trial': False, 'SA': False,'any_validation': True, 'industrial_funding': False, 'physics': ['fluids', 'mechanics'], 'intervention': 'Fontan surgery', 'anatomy': ['Fontan conduit'], 'software': ['InVesalius', 'Geomagic Studio', 'Segment', 'Fluent', 'Ansys meshing', 'SURGEM III'],'demographics': {'sex': True, 'age': True, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': True}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 'Not reported', 'condition': 'apicocaval juxtaposition','females': 7, 'n_patients': 20, 'year': 2020, 'first_author_country': {'USA': 1},                          'all_authors_countries': {'USA': 7, 'India': 5}},
                 {'id': 1900, 'sample': 'twinned', 'trial': False, 'SA': False,'any_validation': True, 'industrial_funding': True, 'physics': ['mechanics'], 'intervention': 'valve replacement', 'anatomy': ['aorta', 'LV', 'RV'], 'software': ['Avizo', 'HyperMesh', 'Abaqus'],'demographics': {'sex': True, 'age': True, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': True}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 3, 'condition': 'aortic stenosis','females': 3, 'n_patients': 3, 'year': 2015, 'first_author_country': {'USA': 1},                          'all_authors_countries': {'USA': 4}},
                 {'id': 2052, 'sample': 'twinned', 'trial': 'prospective, single-blind, multicenter trial', 'SA': False,'any_validation': True, 'industrial_funding': True, 'physics': ['fluids'], 'intervention': 'stent placement', 'anatomy': ['coronary arteries'], 'software': ['QAngioXA-3D', 'QAngio-CT', 'Fluent'],'demographics': {'sex': True, 'age': True, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': True}, 'original_data': False, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 112, 'condition': 'myocardial ischaemia','females': 16, 'n_patients': 56, 'year': 2020, 'first_author_country': {'The Netherlands': 1},              'all_authors_countries': {'The Netherlands': 13, 'Poland': 2, 'Spain': 3, 'France': 2, 'Italy': 1, 'Denmark': 1, 'UK': 4, 'Turkey': 2, 'Ireland': 1}},
                 {'id': 2073, 'sample': 'twinned', 'trial': False, 'SA': False,'any_validation': False, 'industrial_funding': True, 'physics': ['fluids'], 'intervention': 'stent placement', 'anatomy': ['coronary arteries'], 'software': ['ICEM CFD', 'CFX', 'Visual Fortran'],'demographics': {'sex': True, 'age': True, 'BMI': True, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': False, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 86, 'condition': 'myocardial infarction','females': 3, 'n_patients': 43, 'year': 2017, 'first_author_country': {'UK': 1, 'The Netherlands': 1},     'all_authors_countries': {'UK': 1, 'The Netherlands': 3, 'Switzerland': 6, 'Greece': 6, 'Denmark': 1}},
                 {'id': 2122, 'sample': 'population', 'trial': 'In-silico drug trial', 'SA': False,'any_validation': True, 'industrial_funding': True, 'physics': ['electrophysiology'], 'intervention': 'drug delivery', 'anatomy': ['cell'], 'software': ['Virtual Assay'],'demographics': {'sex': False, 'age': False, 'BMI': False, 'weight': False, 'NA': True, 'ethnicity': False, 'comorbidities': False}, 'original_data': False, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 'Unclear but 1213 models x 87 drug trials x unknown number of concentrations', 'condition': 'healthy','females': float('Nan'), 'n_patients': 1213, 'year': 2017, 'first_author_country': {'UK': 1},                           'all_authors_countries': {'UK': 5, 'Belgium': 2}},
                 {'id': 2165, 'sample': 'twinned', 'trial': False, 'SA': False,'any_validation': True, 'industrial_funding': False, 'physics': ['mechanics', 'fluids'], 'intervention': 'recruitment manoeuvres', 'anatomy': ['cardiovascular system'], 'software': ['None reported'],'demographics': {'sex': False, 'age': False, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': False, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 46, 'condition': 'ARDS','females': float('Nan'), 'n_patients': 23, 'year': 2017, 'first_author_country': {'UK': 1},                           'all_authors_countries': {'UK': 7}},
                 {'id': 2205, 'sample': 'twinned', 'trial': False, 'SA': False,'any_validation': True, 'industrial_funding': False, 'physics': ['mechanics', 'fluids'], 'intervention': 'high positive end-expiatory pressure', 'anatomy': ['cardiovascular system'], 'software': ['None reported'],'demographics': {'sex': False, 'age': False, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': False, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': '64-bit Intel Core i7 3.7 GHz Windows 7 personal computer', 'n_simulations': 13, 'condition': 'ARDS','females': float('Nan'), 'n_patients': 13, 'year': 2016, 'first_author_country': {'UK': 1},                           'all_authors_countries': {'UK': 7}},
                 {'id': 2249, 'sample': 'twinned', 'trial': False, 'SA': False,'any_validation': False, 'industrial_funding': False, 'physics': ['fluids'], 'intervention': 'Fontan surgery', 'anatomy': ['Fontan conduit'], 'software': ['None reported'],'demographics': {'sex': True, 'age': True, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 96, 'condition': 'univentricular CHD','females': 18, 'n_patients': 48, 'year': 2014, 'first_author_country': {'USA': 1},                          'all_authors_countries': {'USA': 11}},
                 {'id': 2267, 'sample': 'twinned', 'trial': False, 'SA': False,'any_validation': False, 'industrial_funding': False,'physics': ['fluids'], 'intervention': 'Fontan surgery', 'anatomy': ['Pulmonary veins'], 'software': ['GAMBIT', 'Ansys mesh', 'VMTK'],'demographics': {'sex': True, 'age': True, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 60, 'condition': 'univentricular CHD','females': 37,'n_patients': 60, 'year': 2016, 'first_author_country': {'USA': 1},                          'all_authors_countries': {'USA': 6}},
                 {'id': 2299, 'sample': 'twinned', 'trial': False, 'SA': False,'any_validation': True, 'industrial_funding': False, 'physics': ['fluids'], 'intervention': 'Fontan surgery', 'anatomy': ['Fontan conduit'], 'software': ['Geomagic Studio', 'Gradient Vector', 'Vascular Modeling Toolkit', 'Matlab', 'GAMBIT'],'demographics': {'sex': False, 'age': True, 'BMI': False, 'weight': True, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 5, 'condition': 'univentricular CHD','females': float('Nan'), 'n_patients': 2, 'year': 2013, 'first_author_country': {'China': 1},                        'all_authors_countries': {'China': 6}},
                 {'id': 2320, 'sample': 'twinned', 'trial': False, 'SA': False,'any_validation': True, 'industrial_funding': False, 'physics': ['fluids'], 'intervention': 'Fontan surgery', 'anatomy': ['Fontan conduit'], 'software': ['None reported'],'demographics': {'sex': True, 'age': True, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 120, 'condition': 'univentricular CHD','females': 14, 'n_patients': 40, 'year': 2017, 'first_author_country': {'USA': 1},                          'all_authors_countries': {'USA': 7}},
                 {'id': 2336, 'sample': 'twinned', 'trial': False, 'SA': False,'any_validation': True, 'industrial_funding': False, 'physics': ['fluids'], 'intervention': 'valve replacement', 'anatomy': ['aorta'], 'software': ['Geomagic Studio', 'GAMBIT'],'demographics': {'sex': False, 'age': False, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': False, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 'Unclear because the virtual AVR was optimised', 'condition': 'aortic stenosis','females': float('Nan'), 'n_patients': 5, 'year': 2019, 'first_author_country': {'Germany': 1},                      'all_authors_countries': {'Germany': 9}},
                 {'id': 2345, 'sample': 'twinned', 'trial': False, 'SA': False,'any_validation': True, 'industrial_funding': True, 'physics': ['fluids'], 'intervention': 'Fontan surgery', 'anatomy': ['Fontan conduit'], 'software': ['ZIB Amira', 'Autodesk Meshmixer', 'StarCCM+'],'demographics': {'sex': True, 'age': True, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 53, 'condition': 'univentricular CHD','females': 7, 'n_patients': 12, 'year': 2019, 'first_author_country': {'USA': 1},                          'all_authors_countries': {'USA': 6}},
                 {'id': 2353, 'sample': 'twinned', 'trial': False, 'SA': False, 'any_validation': True, 'industrial_funding': False, 'physics': ['fluids'], 'intervention': 'Fontan surgery', 'anatomy': ['Fontan conduit'], 'software': ['SURGEM III', 'CloudCompare', 'Fluent', 'Geomagic Studio'],'demographics': {'sex': False, 'age': False, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 5, 'condition': 'univentricular CHD','females': float('Nan'), 'n_patients': 5, 'year': 2013, 'first_author_country': {'China': 1},                        'all_authors_countries': {'USA': 1, 'China': 6}},
                 {'id': 2361, 'sample': 'twinned', 'trial': False, 'SA': False, 'any_validation': True, 'industrial_funding': True, 'physics': ['fluids'], 'intervention': 'pericardial patch implant', 'anatomy': ['pulmonary artery', 'aorta', 'coronary arteries'], 'software': ['Geomagic Studio'],'demographics': {'sex': True, 'age': True, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 4, 'condition': 'Tetrallogy of Fallot','females': 2, 'n_patients': 2, 'year': 2014, 'first_author_country': {'USA': 1},                          'all_authors_countries': {'USA': 2}}, 
                 {'id': 2409, 'sample': 'hybrid twinned and SSM', 'trial': False, 'SA': 'Local SA','any_validation': True, 'industrial_funding': False, 'physics': ['electrophysiology'], 'intervention': 'CRT', 'anatomy': ['LV'], 'software': ['ITKSnap', 'Paraview', 'Fluent'],'demographics': {'sex': True, 'age': True, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 104, 'condition': 'HF','females': 11, 'n_patients': 51, 'year': 2019, 'first_author_country': {'UK': 1},                           'all_authors_countries': {'UK': 9, 'Austria': 1}},
                 {'id': 2622, 'sample': 'twinned', 'trial': False, 'SA': 'Discrete SA','any_validation': True, 'industrial_funding': False, 'physics': ['fluids'], 'intervention': 'LA appendage occlusion', 'anatomy': ['LA'], 'software': ['CARP'],'demographics': {'sex': False, 'age': False, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 24, 'condition': 'AF','females': float('Nan'), 'n_patients': 6, 'year': 2021, 'first_author_country': {'Spain': 1},                        'all_authors_countries': {'Spain': 10, 'France': 1}},
                 {'id': 2909, 'sample': 'representative patients', 'trial': False, 'SA': 'They say they do prior to parameter estimation, but do not show the results','any_validation': True, 'industrial_funding': True, 'physics': ['fluids'], 'intervention': 'drug delivery', 'anatomy': ['cardiovascular system'], 'software': ['None reported'],'demographics': {'sex': False, 'age': False, 'BMI': False, 'weight': False, 'NA': True, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 'At least 3 per patient but they also run a sensitivity analysis and a parameter fitting', 'condition': 'HF','females': float('Nan'), 'n_patients': 4, 'year': 2020, 'first_author_country': {'USA': 1},                          'all_authors_countries': {'USA': 3}},
                 {'id': 3029, 'sample': 'twinned', 'trial': False, 'SA': False,'any_validation': True, 'industrial_funding': False, 'physics': ['fluids', 'electrophysiology', 'mechanics'], 'intervention': 'CRT', 'anatomy': ['LV', 'RV'], 'software': ['CircAdapt'],'demographics': {'sex': True, 'age': True, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': '4 patterns * 22 AV delays = 88 simulations at least, seems that more (4 subgroups + potential personalization) but is not clearly stated', 'condition': 'HFy','females': 9, 'n_patients': 87, 'year': 2017, 'first_author_country': {'UK': 1},                           'all_authors_countries': {'UK': 13, 'The Netherlands': 1}},
                 {'id': 4056, 'sample': 'twinned', 'trial': False, 'SA': False,'any_validation': True, 'industrial_funding': True, 'physics': ['electrophysiology'], 'intervention': 'drug delivery', 'anatomy': ['cell'], 'software': ['Cardiac Safety Simulator'],'demographics': {'sex': True, 'age': True, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': False, 'computer': 'Not reported', 'n_simulations': 1300, 'condition': 'arrhythmia','females': 36, 'n_patients': 71, 'year': 2015, 'first_author_country': {'Poland': 1},                       'all_authors_countries': {'Poland': 2, 'UK': 1}},
                 {'id': 4072, 'sample': 'population', 'trial': False, 'SA': 'Not SA, but UQ','any_validation': True, 'industrial_funding': True, 'industrial_funding': False, 'physics': ['fluids'], 'intervention': 'drug delivery', 'anatomy': ['cell'], 'software': ['NONMEM', 'R'],'demographics': {'sex': True, 'age': True, 'BMI': False, 'weight': True, 'NA': False, 'ethnicity': True, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Available upon request', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 20750, 'condition': 'myocardial infarction','females': 365, 'n_patients': 1000, 'year': 2020, 'first_author_country': {'USA': 1},                          'all_authors_countries': {'USA': 8, 'Switzerland': 1}},
                 {'id': 4216, 'sample': 'population', 'trial': False, 'SA': 'UQ through MonteCarlo','any_validation': True, 'industrial_funding': True, 'physics': ['fluids'], 'intervention': 'drug delivery', 'anatomy': ['cell'], 'software': ['R', 'Monolix'],'demographics': {'sex': True, 'age': True, 'BMI': False, 'weight': True, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': False, 'computer': 'Not reported', 'n_simulations': 'Not reported', 'condition': 'HF','females': 663, 'n_patients': 742, 'year': 2018, 'first_author_country': {'Switzerland': 1},                  'all_authors_countries': {'Switzerland': 3}},
                 {'id': 4427, 'sample': 'twinned', 'trial': False, 'SA': 'Local SA','any_validation': True, 'industrial_funding': True, 'physics': ['electrophysiology'], 'intervention': 'CRT', 'anatomy': ['LV', 'RV', 'LA', 'RA', 'aorta', 'pulmonary artery', 'torso'], 'software': ['Python'],'demographics': {'sex': True, 'age': True, 'BMI': False, 'weight': False, 'NA': False, 'ethnicity': False, 'comorbidities': False}, 'original_data': True, 'data_availability': 'Nothing shared', 'open_access': True, 'computer': 'Not reported', 'n_simulations': 8, 'condition': 'univentricular CHD','females': 1, 'n_patients': 24, 'year': 2020, 'first_author_country': {'UK': 1},                           'all_authors_countries': {'UK': 10, 'Austria': 3, 'France': 2}}
        ]

# %%
len(original_data)
# Out:
# 36

# %% [markdown]
# # Bar plot of the publication year

# %%
from collections import Counter
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 16})


all_years = []

for paper in original_data:
    all_years.append(paper['year'])

# Count the number of papers per year
papers_per_year = Counter(all_years)

if not papers_per_year[2012]:
    papers_per_year[2012] = 0

# Create the bar chart
plt.bar(papers_per_year.keys(), papers_per_year.values(), color='black')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Number of papers')
plt.title('ISCTs published per year')

# Set the x-ticks to show all the years
# plt.xticks(range(min(papers_per_year.keys()), max(papers_per_year.keys())+1))

# Show the chart
plt.show()

# %%
from collections import Counter
import matplotlib.pyplot as plt

all_years = []

for paper in original_data:
    all_years.append(paper['year'])

# Count the number of papers per year
papers_per_year = Counter(all_years)

if not papers_per_year[2012]:
    papers_per_year[2012] = 0


# Create the bar chart
bars = plt.bar(papers_per_year.keys(), papers_per_year.values(), color='black')

for year in list(papers_per_year.keys()):    

    for i,bar in enumerate(bars):
        if list(papers_per_year.keys())[i] > year:
            bar.set_color('white')
        else:
            bar.set_color('black')


    # Add labels and title
    plt.xlabel('Year')
    plt.ylabel('Number of papers')
    plt.title('ISCTs published per year')

    # Set the x-ticks to show all the years
    plt.xticks(range(min(papers_per_year.keys()), max(papers_per_year.keys())+1))

    # Show the chart
    plt.savefig('/home/croderog/Desktop/IC_projects/ISCTs_review/figures/papers_until_' + str(year) + '.png', dpi=500, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[68], line 37
#      34 plt.xticks(range(min(papers_per_year.keys()), max(papers_per_year.keys())+1))
#      36 # Show the chart
# ---> 37 plt.savefig('/home/croderog/Desktop/IC_projects/ISCTs_review/figures/papers_until_' + str(year) + '.png', dpi=500, bbox_inches='tight')
#
# File ~/Desktop/IC_projects/ISCTs_review/venv_ISCTs_review/lib/python3.8/site-packages/matplotlib/pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# ...

# %%
id_year = {}

for item in original_data:
    id_year[item["id"]] = item["year"]


{k: v for k, v in sorted(id_year.items(), key=lambda item: item[1])}

# %% [markdown]
# # Geographical distribution of the papers

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np
from plotly.offline import iplot
import plotly.io as pio


country_counts = {}

for paper in original_data:
    countries = paper['first_author_country']
    for country in list(countries.keys()):
        if country in country_counts:
            country_counts[country] += countries[country]
        else:
            country_counts[country] = countries[country]
        
data = dict(
type = 'choropleth',
colorscale = 'Viridis',
locations = list(country_counts.keys()),
locationmode = "country names",
z = list(country_counts.values()),
text = list(country_counts.keys()),
colorbar = {'tickfont': {'size': 20,
                         'color': 'black'},
           'tickvals': list(range(0,np.max(list(country_counts.values()))+1,1)),
           'dtick': 1,
           'x': 1,
           'len': 1.0},
           
)

layout = dict(title='Number of ISCTs papers per affiliation of first author',
              title_font_color = 'black',
              title_x = 0.5,
              title_font_size = 30,
              geo = dict(showcoastlines=True, coastlinecolor="Black",
                         showland=True, landcolor="LightGrey",
                         showocean=True, oceancolor="LightBlue",
                         showlakes=True, lakecolor="LightBlue",
                         showcountries=True, countrycolor="Black",
                         showframe = True,
                         projection = {'type':'equirectangular'})) #The available projections are 'equirectangular', 'mercator', 'orthographic', 'natural earth', 'kavrayskiy7', 'miller', 'robinson', 'eckert4', 'azimuthal equal area', 'azimuthal equidistant', 'conic equal area', 'conic conformal', 'conic equidistant', 'gnomonic', 'stereographic', 'mollweide', 'hammer', 'transverse mercator', 'albers usa', 'winkel tripel', 'aitoff' and 'sinusoidal'.
chmap = go.Figure(data = [data],layout = layout)

iplot(chmap)

pio.write_image(chmap, '/home/croderog/Desktop/IC_projects/ISCTs_review/figures/map_author1.png',width=850)

{k: v for k, v in sorted(country_counts.items(), key=lambda item: item[1], reverse=True)}

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np
from plotly.offline import iplot
                       
country_counts = {}

for paper in original_data:
    countries = paper['all_authors_countries']
    for country in list(countries.keys()):
        if country in country_counts:
            country_counts[country] += countries[country]
        else:
            country_counts[country] = countries[country]
        
data = dict(
type = 'choropleth',
colorscale = 'Viridis',
locations = list(country_counts.keys()),
locationmode = "country names",
z = list(country_counts.values()),
text = list(country_counts.keys()),
colorbar = {'tickfont': {'size': 20,
                         'color': 'black'},
           'tickvals': list(range(0,np.max(list(country_counts.values()))+1,10)),
           'dtick': 1,
           'x': 1},
           
)

layout = dict(title='Number of authors of ISCTs papers per affiliation of all authors',
              title_font_color = 'black',
              title_x = 0.5,
              title_font_size = 30,
              geo = dict(showcoastlines=True, coastlinecolor="Black",
                         showland=True, landcolor="LightGrey",
                         showocean=True, oceancolor="LightBlue",
                         showlakes=True, lakecolor="LightBlue",
                         showcountries=True, countrycolor="Black",
                         showframe = True,
                         projection = {'type':'equirectangular'})) #The available projections are 'equirectangular', 'mercator', 'orthographic', 'natural earth', 'kavrayskiy7', 'miller', 'robinson', 'eckert4', 'azimuthal equal area', 'azimuthal equidistant', 'conic equal area', 'conic conformal', 'conic equidistant', 'gnomonic', 'stereographic', 'mollweide', 'hammer', 'transverse mercator', 'albers usa', 'winkel tripel', 'aitoff' and 'sinusoidal'.
chmap = go.Figure(data = [data],layout = layout)

iplot(chmap)
pio.write_image(chmap, '/home/croderog/Desktop/IC_projects/ISCTs_review/figures/map_author_all.png',width=850)


{k: v for k, v in sorted(country_counts.items(), key=lambda item: item[1], reverse=True)}

# %% [markdown]
# # Industrial funding

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm

plt.rcParams.update({'font.size': 16})


color_scheme = cm.get_cmap("Pastel2")

# Create a list to store the data for each entry
pie_data = []

# Create a list to store the data for the final pie chart
industry = 0
academia = 0

for item in original_data:
    if item["industrial_funding"]:
        industry += 1
    else:
        academia += 1


# Plot a final pie chart
final_data = [industry, academia]
labels_array=["Yes", "No"]

def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.0f}%\n({v:d})'.format(p=pct,v=val)
    return my_autopct

# Plot a final pie chart
plt.figure()
plt.pie(final_data, labels=labels_array,
        colors=[color_scheme(i) for i in range(len(final_data))],
        autopct=make_autopct(final_data), 
        wedgeprops={'linewidth': 1, 'edgecolor': 'black', 'width': 0.35},
        pctdistance=0.5,
       radius=1.4)
plt.title(f"Is the first author funded by industry?", pad=30)
# plt.show()

plt.savefig('/home/croderog/Desktop/IC_projects/ISCTs_review/figures/funding.png', dpi=500, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib

plt.rcParams.update({'font.size': 16})


color_scheme = matplotlib.colormaps.get_cmap("Pastel2")

# Create a list to store the data for each entry
pie_data = []

# Create a list to store the data for the final pie chart
industry = 0
academia = 0

for item in original_data:
    if item["industrial_funding"]:
        industry += 1
    else:
        academia += 1


# Plot a final pie chart
final_data = [industry, academia]
labels_array=["Yes", "No"]

def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.0f}%\n({v:d})'.format(p=pct,v=val)
    return my_autopct

# Plot a final pie chart
plt.figure()
plt.pie(final_data, labels=labels_array,
        colors=[color_scheme(i) for i in range(len(final_data))],
        autopct=make_autopct(final_data), 
        wedgeprops={'linewidth': 1, 'edgecolor': 'black', 'width': 0.35},
        pctdistance=0.5,
       radius=1.4)
plt.title(f"Does the ISCT receive support from industry?", pad=40)
# plt.show()

plt.savefig('/home/croderog/Desktop/IC_projects/ISCTs_review/figures/funding.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# # Physics

# %%
physics = []

for paper in original_data:
    if isinstance(paper['physics'],str):
        physics.append(paper['physics'])
    else:
        physics += paper['physics']

    
physics_dict = {}

for item in physics:
    if item in physics_dict.keys():
        physics_dict[item] += 1
    else:
        physics_dict[item] = 1
                
papers_per_physics = Counter(physics_dict)

sorted_d = dict(sorted(papers_per_physics.items(), key=lambda item: item[1], reverse=False))

plt.barh(list(sorted_d.keys()), [100*v/len(original_data) for v in sorted_d.values()], color=['#FDFD96','#aaa196','#ff6961'])
plt.title('Physics simulated in ISCTs')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().get_xaxis().set_ticks([])


for i, (software, count) in enumerate(sorted_d.items()):
    plt.text(100*count/len(original_data), i, " " + str(round(100*count/len(original_data))) + "%", ha='left', va='center')

# plt.show()

plt.savefig('/home/croderog/Desktop/IC_projects/ISCTs_review/figures/physics.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# # Anatomy analysed

# %%
from collections import Counter
import matplotlib.pyplot as plt
import numpy

anatomy = []

for paper in original_data:
    anatomy += paper['anatomy']
    
anatomy_dict = {}

for item in anatomy:
    if item in anatomy_dict.keys():
        anatomy_dict[item] += 1
    else:
        anatomy_dict[item] = 1
                
papers_per_anatomy = Counter(anatomy_dict)

[(name, number, str(round(100*number/len(original_data))) + "%") for name, number in papers_per_anatomy.most_common()]

# %%
# papers_per_anatomy = {key:val for key, val in papers_per_software.items() if val != 1}

sorted_d = dict(sorted(papers_per_anatomy.items(), key=lambda item: item[1], reverse=False))

plt.barh(list(sorted_d.keys()), [100*v/len(original_data) for v in sorted_d.values()], color='black')
plt.title('Anatomical region of interest in ISCTs')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().get_xaxis().set_ticks([])


for i, (software, count) in enumerate(sorted_d.items()):
    plt.text(100*count/len(original_data), i, " " + str(round(100*count/len(original_data),2)) + "%", ha='left', va='center')

plt.show()

# %% [markdown]
# # Interventions

# %%
intervention = []

for paper in original_data:
    if isinstance(paper['intervention'],str):
        intervention.append(paper['intervention'])
    else:
        intervention += paper['intervention']       
        
    
intervention_dict = {}

for item in intervention:
    if item in intervention_dict.keys():
        intervention_dict[item] += 1
    else:
        intervention_dict[item] = 1

print("Number of interventions: " + str(len(intervention_dict.keys())))        
        
# papers_per_intervention = Counter(intervention_dict)

papers_per_intervention = {key:val for key, val in intervention_dict.items() if val != 1}

sorted_d = dict(sorted(papers_per_intervention.items(), key=lambda item: item[1], reverse=False))

plt.barh(list(sorted_d.keys()), [100*v/len(original_data) for v in sorted_d.values()], color='black')
plt.title('Interventions performed in more than one ISCT')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().get_xaxis().set_ticks([])


for i, (software, count) in enumerate(sorted_d.items()):
    plt.text(100*count/len(original_data), i, " " + str(round(100*count/len(original_data))) + "%", ha='left', va='center')

plt.show()

# %%
import matplotlib

color_scheme = matplotlib.colormaps.get_cmap("Pastel2")

intervention = []

for paper in original_data:
    if isinstance(paper['intervention'], str):
        intervention.append(paper['intervention'])
    else:
        intervention += paper['intervention']       
        
    
intervention_dict = {}

for item in intervention:
    if item in intervention_dict.keys():
        intervention_dict[item] += 1
    else:
        intervention_dict[item] = 1

print("Number of interventions: " + str(len(intervention_dict.keys())))        
        
# papers_per_intervention = Counter(intervention_dict)

papers_per_intervention = {key:val for key, val in intervention_dict.items() if val != 1}

sorted_d = dict(sorted(papers_per_intervention.items(), key=lambda item: item[1], reverse=False))

plt.barh(list(sorted_d.keys()), width=[100*v/len(original_data) for v in sorted_d.values()], color=color_scheme(0), edgecolor='black', hatch='', height=0.9, align='center')
plt.title('Interventions performed in more than one ISCT')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().get_xaxis().set_ticks([])


for i, (software, count) in enumerate(sorted_d.items()):
    plt.text(100*count/len(original_data), i, " " + str(round(100*count/len(original_data))) + "%", ha='left', va='center')

# plt.show()


plt.savefig('/home/croderog/Desktop/IC_projects/ISCTs_review/figures/interventions.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# # Conditions

# %%
import matplotlib.pyplot as plt
import matplotlib


color_scheme = matplotlib.colormaps.get_cmap("Pastel2")


conditions = []

for paper in original_data:
    conditions.append(paper['condition'])
    
conditions_dict = {}

for item in conditions:
    if item in conditions_dict.keys():
        conditions_dict[item] += 1
    else:
        conditions_dict[item] = 1
                
# papers_per_condition = Counter(conditions_dict)
papers_per_condition = {key:val for key, val in conditions_dict.items() if val != 1}

sorted_d = dict(sorted(papers_per_condition.items(), key=lambda item: item[1], reverse=False))

plt.barh(list(sorted_d.keys()), [100*v/len(original_data) for v in sorted_d.values()], color=color_scheme(0), edgecolor='black', hatch='', height=0.9, align='center')
plt.title('Conditions treated in more than one ISCT')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().get_xaxis().set_ticks([])


for i, (software, count) in enumerate(sorted_d.items()):
    plt.text(100*count/len(original_data), i, " " + str(round(100*count/len(original_data))) + "%", ha='left', va='center')

# plt.show()

plt.savefig('/home/croderog/Desktop/IC_projects/ISCTs_review/figures/conditions.png', dpi=500, bbox_inches='tight')

print(round(100*sum([val for key, val in conditions_dict.items() if val == 1])/len(original_data)))

# %% [markdown]
# # Number of patients

# %%
twinned = [paper['id'] for paper in original_data if paper['sample'] == 'twinned']
population = [paper['id'] for paper in original_data if paper['sample'] == 'population']
others = [{paper['id']: paper['sample']} for paper in original_data if paper['sample'] != 'population' and paper['sample'] != 'twinned']

# %%
print('Using digital twins: ' + str(round(100*len(twinned)/len(original_data))) + "\%")
print('Using population models: ' + str(round(100*len(population)/len(original_data))) + "\%")
others

# %%
import matplotlib.pyplot as plt
import matplotlib

plt.rcParams.update({'font.size': 16})

color_scheme = matplotlib.colormaps.get_cmap("Pastel2")

final_data = [len(twinned), len(population), len(others)]
labels_array = ["Digital twin", "Population model", "Others"]

def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.0f}%\n({v:d})'.format(p=pct,v=val)
    return my_autopct

# Plot a final pie chart
plt.figure()
plt.pie(final_data, labels=labels_array,
        colors=[color_scheme(i) for i in range(len(final_data))],
        autopct=make_autopct(final_data), 
        wedgeprops={'linewidth': 1, 'edgecolor': 'black', 'width': 0.35},
        pctdistance=0.55,
       radius=1.4)

# plt.show()

plt.savefig('/home/croderog/Desktop/IC_projects/ISCTs_review/figures/patient_type.png', dpi=500, bbox_inches='tight')

# %%
from collections import Counter
import matplotlib.pyplot as plt
import numpy

plt.rcParams.update({'font.size': 16})


all_patients = []

for paper in original_data:
    if paper['n_patients'] > 1 and paper['sample'] == 'twinned':
        print("#" + str(paper['id']) + ": n=" + str(paper['n_patients']))
        all_patients.append(paper['n_patients'])

papers_per_npatients = Counter(all_patients)

mean = numpy.mean([i for i in all_patients if isinstance(i,int)])
median = numpy.median([i for i in all_patients if isinstance(i,int)])
minv = numpy.min([i for i in all_patients if isinstance(i,int)])
maxv = numpy.max([i for i in all_patients if isinstance(i,int)])

print("Range: [" + str(minv) + ","  + str(maxv) + "]")
print("Average: " + str(round(mean)))
print("Median: " + str(round(median)))

# Create the bar chart
plt.hist(papers_per_npatients.keys(), bins = 10, color=color_scheme(0), edgecolor='black')

# Add labels and title
plt.xlabel('Number of patients')
plt.ylabel('Number of papers')
plt.title('ISCTs sample size')

# Show the chart
# plt.show()

plt.savefig('/home/croderog/Desktop/IC_projects/ISCTs_review/figures/n_patients.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# # Demographics reported

# %%
import matplotlib.pyplot as plt
import matplotlib

plt.rcParams.update({'font.size': 16})

color_scheme = matplotlib.colormaps.get_cmap("Pastel2")

# Create a list to store the data for each entry
pie_data = []

titles = []

sex = 0
sex_age = 0
sex_age_bmi = 0
age = 0
bmi = 0
sex_age_weight = 0
sex_weight = 0
weight = 0
na = 0
ethnicity = 0
sex_age_weight_ethnicity = 0
nothing = 0
sex_age_weight_comorbidities = 0
sex_age_comorbidities = 0
comorbidities = 0


no_population = [paper for paper in original_data if paper['sample'] != 'population']

for item in no_population:
    if item['demographics']['sex'] and item['demographics']['age'] and item['demographics']['weight'] and item['demographics']['ethnicity']:
        sex_age_weight_ethnicity += 1
    elif item['demographics']['sex'] and item['demographics']['age'] and item['demographics']['weight'] and not item['demographics']['comorbidities']:
        sex_age_weight += 1
    elif item['demographics']['sex'] and item['demographics']['age'] and item['demographics']['weight'] and item['demographics']['comorbidities']:
        sex_age_weight_comorbidities += 1
    elif item['demographics']['sex'] and item['demographics']['age'] and item['demographics']['BMI']:
        sex_age_bmi += 1
    elif item['demographics']['sex'] and item['demographics']['age'] and not item['demographics']['comorbidities']:
        sex_age += 1
    elif item['demographics']['sex'] and item['demographics']['age'] and item['demographics']['comorbidities']:
        sex_age_comorbidities += 1
    elif item['demographics']['sex'] and item['demographics']['weight']:
        sex_weight += 1
    elif item['demographics']['sex']:
        sex += 1
    elif item['demographics']['age']:
        age += 1
    elif item['demographics']['BMI']:
        bmi += 1
    elif item['demographics']['weight']:
        weight += 1
    elif item['demographics']['NA']:
        na += 1
    elif item['demographics']['ethnicity']:
        ethnicity += 1
    elif item['demographics']['comorbidities']:
        comorbidities += 1
    else:
        nothing += 1
    
final_data = [age, sex, comorbidities, sex_age, sex_age_comorbidities, sex_age_bmi, bmi, sex_age_weight, sex_age_weight_comorbidities, sex_weight, weight, ethnicity, sex_age_weight_ethnicity, na + nothing]
labels_array=["age", "Sex/gender", "Comorbidities", "Sex/gender and age", "Sex/gender, age and comorbidities", "Sex/gender, age and BMI", "BMI", "Sex/gender, age and weight", "Sex/gender, age, weight and comorbidities", "Sex/gender and weight", "Weight", "Ethnicity", "Sex/gender, age, weight and ethnicity", "Nothing"]

entries_to_show = [i for i, val in enumerate(final_data) if val > 0]

final_data = [final_data[i] for i in entries_to_show]
labels_array = [labels_array[i] for i in entries_to_show]


def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.0f}%\n({v:d})'.format(p=pct,v=val)
    return my_autopct

# Plot a final pie chart
plt.figure()
plt.pie(final_data, labels=labels_array,
        colors=[color_scheme(i) for i in range(len(final_data))],
        autopct=make_autopct(final_data), 
        wedgeprops={'linewidth': 1, 'edgecolor': 'black', 'width': 0.35},
        pctdistance=0.67,
       radius=1.6)
plt.title(f"Basic demographics reported in ISCTs", pad=70)
# plt.show()

plt.savefig('/home/croderog/Desktop/IC_projects/ISCTs_review/figures/demographics.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# # Female representation

# %%
import matplotlib.pyplot as plt
import matplotlib

plt.rcParams.update({'font.size': 16})


# Get the viridis colormap
color_scheme = matplotlib.colormaps.get_cmap("Pastel2")

# Create a list to store the data for each entry
pie_data = []

titles = []
total_patients = 0

# Create a list to store the data for the final pie chart
final_data = [0, 0]

for item in original_data:
    # Check if 'females' key has a valid value
    if not isinstance(item["females"], float) and item['sample'] != 'population':
        # Add data to the list for each entry
        pie_data.append([item["females"], item["n_patients"] - item["females"]])
        titles.append(item["id"])
        # Add data to the list for the final pie chart
        final_data[0] += item["females"]
        final_data[1] += item["n_patients"] - item["females"]
        total_patients += item["n_patients"]
        
# Plot a pie chart for each entry
for i, data in enumerate(pie_data):
    plt.figure()
    if data[1] == 0:
        plt.pie(data, labels=["Women", ""], colors=[color_scheme(i) for i in range(len(data))],
        autopct='%1.f%%')
    elif data[0] == 0:
        plt.pie(data, labels=["", "Men"], colors=[color_scheme(i) for i in range(len(data))],
        autopct='%1.f%%')
    else:
        plt.pie(data, labels=["Women", "Men"], colors=[color_scheme(i) for i in range(len(data))],
        autopct='%1.f%%')
    
    plt.title(f"Paper #{titles[i]} (n={data[0]+data[1]})")
    plt.savefig("/home/croderog/Desktop/IC_projects/ISCTs_review/figures/" + "Paper #" + str(titles[i]) + ".png", dpi=500, bbox_inches='tight')

# Plot a final pie chart
labels_array = ["Women", "Men"]
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.0f}%\n({v:d})'.format(p=pct,v=val)
    return my_autopct

# Plot a final pie chart
plt.figure()
plt.pie(final_data, labels=labels_array,
        colors=[color_scheme(i) for i in range(len(final_data))],
        autopct=make_autopct(final_data), 
        wedgeprops={'linewidth': 1, 'edgecolor': 'black', 'width': 0.35},
        pctdistance=0.55,
       radius=1.4)
plt.title(f"Total (n={total_patients})", pad=50)
# plt.show()
plt.savefig("/home/croderog/Desktop/IC_projects/ISCTs_review/figures/total.png", dpi=500, bbox_inches='tight')

# %%
from collections import Counter
import matplotlib.pyplot as plt
import numpy

plt.rcParams.update({'font.size': 16})


perc_females = []

for paper in pie_data:
    perc_females.append(100*paper[0]/(paper[0]+paper[1]))

papers_per_perc_females = Counter(perc_females)

# Create the bar chart
plt.hist(papers_per_perc_females, bins = 10, color=color_scheme(0), edgecolor='black')

# Add labels and title
plt.xlabel('Percentage of women in studies (%)')
plt.ylabel('Number of papers')
plt.title('Percentage of women in ISCTs')

# Show the chart
# plt.show()

mean = round(numpy.mean(perc_females))
median = round(numpy.median(perc_females))
print("Mean: " + str(mean))
print("Median: " + str(median))

plt.savefig('/home/croderog/Desktop/IC_projects/ISCTs_review/figures/women.png', dpi=500, bbox_inches='tight')

# %%
from collections import Counter
import matplotlib.pyplot as plt
import numpy

plt.rcParams.update({'font.size': 16})


perc_females = []

for paper in pie_data:
    if (paper[0]+paper[1]) >5:
        perc_females.append(100*paper[0]/(paper[0]+paper[1]))

papers_per_perc_females = Counter(perc_females)

# Create the bar chart
plt.hist(papers_per_perc_females, bins = 10, color=color_scheme(0), edgecolor='black', range=(0,100))

# Add labels and title
plt.xlabel('Percentage of women in studies (%)')
plt.ylabel('Number of papers')
plt.title('Percentage of women in ISCTs with n>5')

# Show the chart
# plt.show()

mean = round(numpy.mean(perc_females))
median = round(numpy.median(perc_females))
print("Mean: " + str(mean))
print("Median: " + str(median))

plt.savefig('/home/croderog/Desktop/IC_projects/ISCTs_review/figures/women_100.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# # Validation

# %%
import matplotlib.pyplot as plt
import matplotlib

plt.rcParams.update({'font.size': 16})

color_scheme = matplotlib.colormaps.get_cmap("Pastel2")

# Create a list to store the data for each entry
pie_data = []

# Create a list to store the data for the final pie chart
validated = 0
not_validated = 0

for item in original_data:
    if item["any_validation"]:
        validated += 1
    else:
        not_validated += 1


# Plot a final pie chart
final_data = [validated, not_validated]
labels_array = ["Yes", "No"]

def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.0f}%\n({v:d})'.format(p=pct,v=val)
    return my_autopct

# Plot a final pie chart
plt.figure()
plt.pie(final_data, labels=labels_array,
        colors=[color_scheme(i) for i in range(len(final_data))],
        autopct=make_autopct(final_data), 
        wedgeprops={'linewidth': 1, 'edgecolor': 'black', 'width': 0.35},
        pctdistance=0.55,
       radius=1.4)
plt.title(f"Does the ISCT perform any kind of validation?", pad=50)
# plt.show()

plt.savefig('/home/croderog/Desktop/IC_projects/ISCTs_review/figures/validation.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# # Sensitivity analysis

# %%
import matplotlib.pyplot as plt
import matplotlib

plt.rcParams.update({'font.size': 16})


color_scheme = matplotlib.colormaps.get_cmap("Pastel2")

# Create a list to store the data for each entry
pie_data = []

# Create a list to store the data for the final pie chart
SA = 0
not_SA = 0

for item in original_data:
    if item["SA"]:
        SA += 1
    else:
        not_SA += 1


# Plot a final pie chart
final_data = [SA, not_SA]
labels_array = ["Yes", "No"]

def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.0f}%\n({v:d})'.format(p=pct,v=val)
    return my_autopct

# Plot a final pie chart
plt.figure()
plt.pie(final_data, labels=labels_array,
        colors=[color_scheme(i) for i in range(len(final_data))],
        autopct=make_autopct(final_data), 
        wedgeprops={'linewidth': 1, 'edgecolor': 'black', 'width': 0.35},
        pctdistance=0.55,
       radius=1.4)
plt.title(f"Does the ISCT have any kind of sensitivity analysis?", pad=50)
# plt.show()

plt.savefig('/home/croderog/Desktop/IC_projects/ISCTs_review/figures/SA.png', dpi=500, bbox_inches='tight')

# %%
for item in original_data:
    if item["SA"]:
        print(item["SA"])
        print(item["id"])

# %% [markdown]
# # Data used

# %%
import matplotlib.pyplot as plt
import matplotlib

color_scheme = matplotlib.colormaps.get_cmap("Pastel2")

# Create a list to store the data for each entry
pie_data = []

# Create a list to store the data for the final pie chart
final_data = [0, 0]

for item in original_data:
    if item["original_data"]:
        final_data[0] += 1
    else:
        final_data[1] += 1


# Plot a final pie chart
plt.figure()
plt.pie(final_data, labels=["Original data", "Data from literature"], 
        colors=[color_scheme(i) for i in range(len(final_data))],
        autopct='%1.f%%')
plt.title(f"Type of clinical data used per study")
# plt.show()

plt.savefig('/home/croderog/Desktop/IC_projects/ISCTs_review/figures/data.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# # Types of computers used

# %%
from collections import Counter
import matplotlib.pyplot as plt
import numpy

computers = []

for paper in original_data:
    computers.append(paper['computer'])

papers_per_computer = Counter(computers)

papers_per_computer.most_common()

# %% [markdown]
# # Software

# %%
from collections import Counter
import matplotlib.pyplot as plt
import numpy

software = []

for paper in original_data:
    software += paper['software']
    
software_dict = {}

for s in software:
    if s in software_dict.keys():
        software_dict[s] += 1
    else:
        software_dict[s] = 1
        
papers_per_software = Counter(software_dict)

[(name, number, str(round(100*number/len(original_data))) + "%") for name, number in papers_per_software.most_common()]
# Out:
# [('Fluent', 7, '19%'),
#  ('Geomagic Studio', 6, '17%'),
#  ('None reported', 5, '14%'),
#  ('simvascular', 3, '8%'),
#  ('GAMBIT', 3, '8%'),
#  ('Matlab', 2, '6%'),
#  ('CircAdapt', 2, '6%'),
#  ('Ansys meshing', 2, '6%'),
#  ('ITKSnap', 2, '6%'),
#  ('Abaqus', 2, '6%'),
#  ('SURGEM III', 2, '6%'),
#  ('R', 2, '6%'),
#  ('ZIB-Amira', 1, '3%'),
#  ('CellML', 1, '3%'),
#  ('C++', 1, '3%'),
#  ('CVODE', 1, '3%'),
#  ('Chaste', 1, '3%'),
#  ('openCARP', 1, '3%'),
#  ('graphpad prism', 1, '3%'),
#  ('Ansys', 1, '3%'),
#  ('QMass', 1, '3%'),
#  ('ADINA', 1, '3%'),
#  ('Mimics', 1, '3%'),
#  ('ScanIp', 1, '3%'),
#  ('VMTKLab', 1, '3%'),
#  ('OsiriX', 1, '3%'),
#  ('Seg3D', 1, '3%'),
#  ('meshtool', 1, '3%'),
#  ('3DSlicer', 1, '3%'),
#  ('Ansys CFX', 1, '3%'),
#  ('SPSS', 1, '3%'),
#  ('InVesalius', 1, '3%'),
#  ('Segment', 1, '3%'),
#  ('Avizo', 1, '3%'),
#  ('HyperMesh', 1, '3%'),
#  ('QAngioXA-3D', 1, '3%'),
#  ('QAngio-CT', 1, '3%'),
#  ('ICEM CFD', 1, '3%'),
#  ('CFX', 1, '3%'),
# ...

# %%
import matplotlib

color_scheme = matplotlib.colormaps.get_cmap("Pastel2")

papers_per_software = {key:val for key, val in papers_per_software.items() if val != 1}

sorted_d = dict(sorted(papers_per_software.items(), key=lambda item: item[1], reverse=False))

plt.barh(list(sorted_d.keys()), [100*v/len(original_data) for v in sorted_d.values()], color=color_scheme(0), edgecolor='black')
plt.title('Software used in more than one ISCT')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().get_xaxis().set_ticks([])


for i, (software, count) in enumerate(sorted_d.items()):
    plt.text(100*count/len(original_data), i, " " + str(round(100*count/len(original_data))) + "%", ha='left', va='center')

# plt.show()

plt.savefig('/home/croderog/Desktop/IC_projects/ISCTs_review/figures/software.png', dpi=500, bbox_inches='tight')

# %%
papers_per_software = {key:val for key, val in papers_per_software.items() if val != 1}

sorted_d = dict(sorted(papers_per_software.items(), key=lambda item: item[1], reverse=True))

# Get the first 5 items in the sorted dictionary
top_5 = dict(list(sorted_d.items())[:5])

# Sort the top 5 items in descending order
top_5 = dict(sorted(top_5.items(), key=lambda item: item[1], reverse=False))

plt.barh(list(top_5.keys()), [100*v/len(original_data) for v in top_5.values()], color=['#e13239','#00fd02','black','#074c99','#f3d70d'])
plt.title('Software most reported in ISCTs')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().get_xaxis().set_ticks([])

for i, (software, count) in enumerate(top_5.items()):

    plt.text(100*count/len(original_data), i, " " + str(round(100*count/len(original_data))) + "%", ha='left', va='bottom')

# plt.show()

plt.savefig('/home/croderog/Desktop/IC_projects/ISCTs_review/figures/software.png', dpi=500, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 papers_per_software = {key:val for key, val in papers_per_software.items() if val != 1}
#       3 sorted_d = dict(sorted(papers_per_software.items(), key=lambda item: item[1], reverse=True))
#       5 # Get the first 5 items in the sorted dictionary
#
# NameError: name 'papers_per_software' is not defined

# %% [markdown]
# # Open access

# %%
import matplotlib.pyplot as plt
import matplotlib

plt.rcParams.update({'font.size': 16})


color_scheme = matplotlib.colormaps.get_cmap("Pastel2")

# Create a list to store the data for each entry
pie_data = []

# Create a list to store the data for the final pie chart
final_data = [0, 0]

for item in original_data:
    if item["open_access"]:
        final_data[0] += 1
    else:
        final_data[1] += 1


# Plot a final pie chart
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.0f}%\n({v:d})'.format(p=pct,v=val)
    return my_autopct

# Plot a final pie chart
plt.figure()
plt.pie(final_data, labels=labels_array,
        colors=[color_scheme(i) for i in range(len(final_data))],
        autopct=make_autopct(final_data), 
        wedgeprops={'linewidth': 1, 'edgecolor': 'black', 'width': 0.35},
        pctdistance=0.55,
       radius=1.4)
plt.title(f"Percentage of ISCTs open access", pad=50)
# plt.show()

plt.savefig('/home/croderog/Desktop/IC_projects/ISCTs_review/figures/open_access.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# # Data availability statement

# %%
from collections import Counter
import matplotlib.pyplot as plt
import numpy

statements = []

for paper in original_data:
    statements.append(paper['data_availability'])

papers_per_statement = Counter(statements)

papers_per_statement.most_common()

# %%
import matplotlib.pyplot as plt
import matplotlib

plt.rcParams.update({'font.size': 16})

color_scheme = matplotlib.colormaps.get_cmap("Pastel2")

# Create a list to store the data for each entry
pie_data = []

titles = []

nothing = 0
request = 0
shared = 0
willbe = 0

for item in original_data:
    if item['data_availability'] == 'Nothing shared':
        nothing += 1
    elif item['data_availability'] == 'Available upon request':
        request += 1
    elif item['data_availability'] == 'Data and scripts shared':
        shared += 1
    else:
        willbe +=1
    
final_data = [shared, willbe, request, nothing]
labels_array=["Data and scripts shared", "Data will be made available", "Available upon request", "Nothing shared"]


# Plot a final pie chart
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.0f}% ({v:d})'.format(p=pct,v=val)
    return my_autopct

# Plot a final pie chart
plt.figure()
plt.pie(final_data, labels=labels_array,
        colors=[color_scheme(i) for i in range(len(final_data))],
        autopct=make_autopct(final_data), 
        wedgeprops={'linewidth': 1, 'edgecolor': 'black', 'width': 0.35},
        pctdistance=0.5,
       radius=1.4)
plt.title(f"Data availability statement in ISCTs", pad=60)
# plt.show()

plt.savefig('/home/croderog/Desktop/IC_projects/ISCTs_review/figures/data_availability.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# # Number of simulations

# %%
from collections import Counter
import matplotlib.pyplot as plt
import numpy

n_simulations = []

for paper in original_data:
    n_simulations.append(paper['n_simulations'])

papers_per_n_simulation = Counter(n_simulations)

papers_to_plot = Counter({k: v for k, v in papers_per_n_simulation.items() if not isinstance(k, str)})


# Create the bar chart
plt.hist(papers_to_plot, bins = 10, color='black')

# Add labels and title
plt.xlabel('Number of simulations reported')
plt.ylabel('Number of papers')
plt.title('Number of simulation reported in ISCTs')

# # Show the chart
plt.show()

# %%
from collections import Counter
import matplotlib.pyplot as plt
import numpy

n_simulations = []

for paper in original_data:
    n_simulations.append(paper['n_simulations'])

papers_per_n_simulation = Counter(n_simulations)

papers_to_plot = Counter({k: v for k, v in papers_per_n_simulation.items() if not isinstance(k, str)})


# Create the bar chart
plt.hist(papers_to_plot, bins = 100, color='black', range=(0,1500))

# Add labels and title
plt.xlabel('Number of simulations reported')
plt.ylabel('Number of papers')
plt.title('Number of simulation reported in ISCTs')

# Show the chart
plt.show()


mean = numpy.average([k for k, v in papers_per_n_simulation.items() if not isinstance(k, str)])
median = numpy.median([k for k, v in papers_per_n_simulation.items() if not isinstance(k, str)])
print("Average: " + str(mean))
print("Median: " + str(median))

# %%
from collections import Counter
import matplotlib.pyplot as plt
import numpy

n_simulations = []

for paper in original_data:
    n_simulations.append(paper['n_simulations'])
    if not isinstance(paper['n_simulations'], str):
        print(str(paper['id']) + ":" + str(paper['n_simulations']))

papers_per_n_simulation = Counter(n_simulations)

papers_to_plot = Counter({k: v for k, v in papers_per_n_simulation.items() if not isinstance(k, str)})


# Create the bar chart
plt.hist(papers_to_plot, bins = 10, color='black', range=(0,200))

# Add labels and title
plt.xlabel('Number of simulations reported')
plt.ylabel('Number of papers')
plt.title('Number of simulation reported in ISCTs')

# Show the chart
plt.show()

mean = numpy.average([k for k, v in papers_per_n_simulation.items() if not isinstance(k, str) and k < 200])
median = numpy.median([k for k, v in papers_per_n_simulation.items() if not isinstance(k, str)and k < 200])
print("Average: " + str(mean))
print("Median: " + str(median))
print(sum([v for k, v in papers_per_n_simulation.items() if not isinstance(k, str) and k < 10]))

# %%
import matplotlib.pyplot as plt
import matplotlib

color_scheme = matplotlib.colormaps.get_cmap("Pastel2")

# Create a list to store the data for each entry
pie_data = []

titles = []
total_patients = 0

# Create a list to store the data for the final pie chart
final_data = [0, 0, 0]

for item in original_data:
    if not isinstance(item["n_simulations"], str):
        # Add data to the list for the final pie chart
        final_data[0] += 1
    elif item["n_simulations"] == 'Not reported':
        final_data[1] += 1
    else:
        final_data[2] += 1


# Plot a final pie chart
plt.figure()
plt.pie(final_data, labels=["Reported/clear", "Not reported", "Not clear"], 
        colors=[color_scheme(i) for i in range(len(final_data))],
        autopct='%1.2f%%')
plt.title(f"Papers reporting of the number of simulations")
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib

color_scheme = matplotlib.colormaps.get_cmap("Pastel2")

sim_per_patient_dict = {}

for item in original_data:
    if isinstance(item["n_simulations"], int) and isinstance(item["n_patients"], int):
        sim_per_patient = round(item["n_simulations"]/item["n_patients"],2)
        if sim_per_patient in sim_per_patient_dict.keys():
            sim_per_patient_dict[sim_per_patient] += 1
        else:
            sim_per_patient_dict[sim_per_patient] = 1


sim_per_patient_c = Counter(sim_per_patient_dict)


# Create the bar chart
plt.hist(sim_per_patient_c, color='black')

# Add labels and title
plt.xlabel('Number of simulations per patient')
plt.ylabel('Number of papers')
plt.title('Number of simulations per patients reported in ISCTs')
plt.xlim(left=1)

plt.xticks(numpy.arange(1,int(max(sim_per_patient_c.keys())+1), 2))

# Show the chart
plt.show()

mean = numpy.average([k for k, v in sim_per_patient_dict.items() ])
median = numpy.median([k for k, v in sim_per_patient_dict.items()])
print("Average: " + str(mean))
print("Median: " + str(median))

# %% [markdown]
# # Trial terminology

# %%
import matplotlib.pyplot as plt
import matplotlib

color_scheme = matplotlib.colormaps.get_cmap("Pastel2")

# Create a list to store the data for each entry
pie_data = []

# Create a list to store the data for the final pie chart
trial = 0
not_trial = 0

for item in original_data:
    if item["trial"]:
        trial += 1
    else:
        not_trial += 1


# Plot a final pie chart
plt.figure()
plt.pie([trial, not_trial], labels=["Yes", "No"], 
        colors=[color_scheme(i) for i in range(len([trial, not_trial]))],
        autopct='%1.2f%%')
plt.title(f"Is the ISCT self-referred to as \"trial\"?")
plt.show()

# %%
for item in original_data:
    if item["trial"]:
        print(item["trial"])
